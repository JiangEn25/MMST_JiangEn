# %%
import pandas as pd

# %%
df = pd.read_csv('seeds.csv')
print(df)
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    15.26      14.84       0.8710        100.000         3.312
# 2    15.26      14.84       0.8710        200.000         3.312
# 3    15.26      14.84       0.8710        300.000         3.312
# 4    14.88      14.57       0.8811          5.554         3.333
# ..     ...        ...          ...            ...           ...
# 197  12.19      13.20       0.8783          5.137         2.981
# 198  11.23      12.88       0.8511          5.140         2.795
# 199  13.20      13.66       0.8883          5.236         3.232
# 200  11.84      13.21       0.8521          5.175         2.836
# 201  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220   1.0
# 1              2.221          5.220   NaN
# 2              2.221          5.220   1.0
# 3              2.221          5.220   1.0
# 4              1.018          4.956   NaN
# ..               ...            ...   ...
# 197            3.631          4.870   3.0
# 198            4.325          5.003   3.0
# 199            8.315          5.056   3.0
# 200            3.598          5.044   3.0
# 201            5.637          5.063   3.0
#
# [202 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Area               0
# Perimeter          0
# Compactness        0
# Kernel.Length      0
# Kernel.Width       0
# Asymmetry.Coeff    0
# Kernel.Groove      6
# Type               3
# dtype: int64

# %%
Kernel_Groove_Mean = df["Kernel.Groove"].mean()
print(Kernel_Groove_Mean)
df["Kernel.Groove"].fillna(Kernel_Groove_Mean, inplace = True) 
df["Type"].fillna(1, inplace = True) 
print(df)
df.isna().sum()
# Out:
# 5.432479591836735
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    15.26      14.84       0.8710        100.000         3.312
# 2    15.26      14.84       0.8710        200.000         3.312
# 3    15.26      14.84       0.8710        300.000         3.312
# 4    14.88      14.57       0.8811          5.554         3.333
# ..     ...        ...          ...            ...           ...
# 197  12.19      13.20       0.8783          5.137         2.981
# 198  11.23      12.88       0.8511          5.140         2.795
# 199  13.20      13.66       0.8883          5.236         3.232
# 200  11.84      13.21       0.8521          5.175         2.836
# 201  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220   1.0
# 1              2.221          5.220   1.0
# 2              2.221          5.220   1.0
# 3              2.221          5.220   1.0
# 4              1.018          4.956   1.0
# ..               ...            ...   ...
# 197            3.631          4.870   3.0
# 198            4.325          5.003   3.0
# 199            8.315          5.056   3.0
# 200            3.598          5.044   3.0
# 201            5.637          5.063   3.0
#
# [202 rows x 8 columns]
# Area               0
# Perimeter          0
# Compactness        0
# Kernel.Length      0
# Kernel.Width       0
# Asymmetry.Coeff    0
# Kernel.Groove      0
# Type               0
# dtype: int64

# %%
for x in df.index:
  if df.loc[x, "Kernel.Length"] > 10:
    df.drop(x, inplace = True) 
print(df)
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 4    14.88      14.57       0.8811          5.554         3.333
# 5    14.29      14.09       0.9050          5.291         3.000
# 7    16.14      14.99       0.9034          5.658         3.562
# 9    14.69      14.49       0.8799          5.563         3.000
# ..     ...        ...          ...            ...           ...
# 197  12.19      13.20       0.8783          5.137         2.981
# 198  11.23      12.88       0.8511          5.140         2.795
# 199  13.20      13.66       0.8883          5.236         3.232
# 200  11.84      13.21       0.8521          5.175         2.836
# 201  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220   1.0
# 4              1.018          4.956   1.0
# 5              2.699          4.825   1.0
# 7              1.355          5.175   1.0
# 9              3.586          5.219   1.0
# ..               ...            ...   ...
# 197            3.631          4.870   3.0
# 198            4.325          5.003   3.0
# 199            8.315          5.056   3.0
# 200            3.598          5.044   3.0
# 201            5.637          5.063   3.0
#
# [195 rows x 8 columns]

# %%
print(df.duplicated().to_string())
# Out:
# 0      False
# 4      False
# 5      False
# 7      False
# 9      False
# 10     False
# 12     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18      True
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# 158    False
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False

# %%
df.drop_duplicates(inplace = True)

# %%
print(df.duplicated().to_string())
# Out:
# 0      False
# 4      False
# 5      False
# 7      False
# 9      False
# 10     False
# 12     False
# 14     False
# 15     False
# 16     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# 158    False
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
KNN_model = KNeighborsClassifier(n_neighbors=5)

# %%
X = df.iloc[:,0:7]
print(X)
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 4    14.88      14.57       0.8811          5.554         3.333
# 5    14.29      14.09       0.9050          5.291         3.000
# 7    16.14      14.99       0.9034          5.658         3.562
# 9    14.69      14.49       0.8799          5.563         3.000
# ..     ...        ...          ...            ...           ...
# 197  12.19      13.20       0.8783          5.137         2.981
# 198  11.23      12.88       0.8511          5.140         2.795
# 199  13.20      13.66       0.8883          5.236         3.232
# 200  11.84      13.21       0.8521          5.175         2.836
# 201  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove
# 0              2.221          5.220
# 4              1.018          4.956
# 5              2.699          4.825
# 7              1.355          5.175
# 9              3.586          5.219
# ..               ...            ...
# 197            3.631          4.870
# 198            4.325          5.003
# 199            8.315          5.056
# 200            3.598          5.044
# 201            5.637          5.063
#
# [192 rows x 7 columns]

# %%
y = df['Type']
print(y)
# Out:
# 0      1.0
# 4      1.0
# 5      1.0
# 7      1.0
# 9      1.0
#       ...
# 197    3.0
# 198    3.0
# 199    3.0
# 200    3.0
# 201    3.0
# Name: Type, Length: 192, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=33)
X_train.info()
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153 entries, 83 to 30
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             153 non-null    float64
#  1   Perimeter        153 non-null    float64
#  2   Compactness      153 non-null    float64
#  3   Kernel.Length    153 non-null    float64
#  4   Kernel.Width     153 non-null    float64
#  5   Asymmetry.Coeff  153 non-null    float64
#  6   Kernel.Groove    153 non-null    float64
# dtypes: float64(7)
# memory usage: 9.6 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 97 to 113
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             39 non-null     float64
#  1   Perimeter        39 non-null     float64
#  2   Compactness      39 non-null     float64
#  3   Kernel.Length    39 non-null     float64
#  4   Kernel.Width     39 non-null     float64
#  5   Asymmetry.Coeff  39 non-null     float64
#  6   Kernel.Groove    39 non-null     float64
# dtypes: float64(7)
# memory usage: 2.4 KB

# %%
KNN_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
KNN_prediction = KNN_model.predict(X_test)
print(accuracy_score(KNN_prediction, y_test))
# Out:
# 0.8717948717948718

# %%
print(classification_report(KNN_prediction, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.75      0.82      0.78        11
#          2.0       1.00      0.75      0.86        12
#          3.0       0.89      1.00      0.94        16
#
#     accuracy                           0.87        39
#    macro avg       0.88      0.86      0.86        39
# weighted avg       0.88      0.87      0.87        39
